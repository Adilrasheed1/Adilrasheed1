# %% [markdown]
# <a href="https://colab.research.google.com/github/Adilrasheed1/Adilrasheed1/blob/main/introToPyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Output

# %%
print("hello world")
# Out:
# hello world

# %%
print(10)
# Out:
# 10

# %% [markdown]
# 2. Data Types

# %%
#integer
print(8*10*17)
# Out:
# 1360

# %%
#float
print(1.5+3.2+1+2.4*3)
# Out:
# 12.899999999999999

# %%
#boolean
print(1==1)
print(False)
# Out:
# True
# False

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#dictionary
print({"name":"Adil Rasheed","Degree":"bTech CSE","sem":"8th","Roll Number":22048112022,})
# Out:
# {'name': 'Adil Rasheed', 'Degree': 'bTech CSE', 'sem': '8th', 'Roll Number': 22048112022}

# %%
#type
type(2.5)
type(3)
type([1,2,3])
type({1,2,3})
type((1,23,4,5,6,7,8,9))
type({"name":"Adil Rasheed","age":23,})
# Out:
# dict

# %% [markdown]
# 3. Variables

# %%
name="Adil Rasheed";
age=23;
batch=2022;
sem="8th";
print(name)
print(age)
print(batch)
print(sem)
# Out:
# Adil Rasheed
# 23
# 2022
# 8th

# %%
#dynamic binding
a=10;
print(a);
a="adil"
print(a);
# Out:
# 10
# adil

# %%
#different styles of variable declaration
a,b,c=10,2,3;
print(a,b,c)
#it also simplifies to a=10,b=2,c=3
a=b=c=3  #if all the variables have same value equal to 3
print(a,b,c)
# Out:
# 10 2 3
# 3 3 3

# %% [markdown]
# 4.Keywords And Identifiers

# %%
#keyword are the reserved words in python and cannot be used for variables
#e.g print, def, if ,else, return etc are keywords

# %%
#identifers are simply names used to identify  a variable ,class ,function or other object.
#rules
 #you can't start with a digit
 #you can only use one special charater i.e; _
 #

# %% [markdown]
# 6.User Input

# %%
input("enter your Name : ")
# Out:
# enter your Name : adil rasheed
# 'adil rasheed'

# %%
#take two inputs from user and add them and print the  result to user
a=input("enter first num: ")
b=input("enter second num: ")
c=int(a)+int(b)
print(c)
type(a)
# Out:
# enter first num: 1
# enter second num: 2
# 3
# str

# %% [markdown]
# 7. Literals

# %%
#literals are the values stored in a variable
#integer literal
a=0b1010 #binary literal
b=100 #decimal literal
c=0o317 #0ctal literal
d=0x12c #hexadecimal
print(a)
print(b)
print(c)
print(d)
#float literal
float_1=1.3e2 #1.3*10^2
print(float_1)
# Out:
# 10
# 100
# 207
# 300
# 130.0
